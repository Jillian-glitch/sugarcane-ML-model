# %% [markdown]
# <a href="https://colab.research.google.com/github/Jillian-glitch/sugarcane-web-app/blob/main/sugarcrop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install earthengine-api==0.1.272
# !pip install streamlit
# !pip install folium
# !pip install numpy
# !pip install geopandas
# !pip install pandas

# Authenticate with Earth Engine
from google.colab import auth
auth.authenticate_user()
# !earthengine authenticate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.2/229.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for earthengine-api: filename=earthengine_api-0.1.272-py3-none-any.whl size=257974 sha256=cbe12ca5b7f6b64dc8a8acb1d706f5cd910daac0cd68fbdf095a942eddfb02fd
#   Stored in directory: /root/.cache/pip/wheels/e0/01/05/8ea2d3b86aa9dcf5ca67fdfc1138994ab99a460f702a362954
# ...
#   Created wheel for httplib2shim: filename=httplib2shim-0.0.3-py2.py3-none-any.whl size=18043 sha256=8eca30964f144f6fb3cd11523613fb67253e52ff74f19067be84be2943a80f70
#   Stored in directory: /root/.cache/pip/wheels/88/e5/dd/0096092515d7a3711c1bbc6c2ea1933a1fe1a62da93a6072a0
# Successfully built earthengine-api httplib2shim
# ...
#   Attempting uninstall: uritemplate
#     Found existing installation: uritemplate 4.1.1
#     Uninstalling uritemplate-4.1.1:
# ...
